# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import math
import numpy as np
def func(x):
    return math.sin(x/5.) * math.exp(x/10.) + 5 * math.exp(-x/2.)
# f(x) = sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)
#sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)
x = np.arange(1.,16.,0.2)
y = [func(z) for z in x]
print y
print y0
y0 = [3.43914511 - 0.18692825*z for z in x]
y1 = [3.32512949 - 0.06531159*z - 0.00760104*z**2 for z in x]
y2 = [4.36264154 - 1.29552587*z + 0.19333685*z**2 -0.00823565*z**3 for z in x]
y3 = [4.64220242e+00 -1.68016922e+00*z + 3.09983260e-01 *z**2 -2.01863246e-02 * z**3 + 3.86729268e-04 * z**4
 for z in x]
plt.plot(x, y)
plt.plot(x,y0)
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
# Out:
# [3.252216865271419, 3.012067143378875, 2.8008111806665434, 2.6157920991196266, 2.454597127360356, 2.315033843231159, 2.1951086745479764, 2.0930074441042397, 2.0070777654062413, 1.9358131140793273, 1.8778384165859365, 1.8318970130082932, 1.7968388643216167, 1.7716098869548662, 1.7552423086290905, 1.7468459495903677, 1.7456003425164714, 1.7507476126654336, 1.7615860473330907, 1.7774642904705569, 1.797776104449257, 1.821955646512166, 1.8494732124708266, 1.8798314047488578, 1.9125616859795516, 1.9472212830789883, 1.9833904100741222, 2.0206697810012297, 2.0586783869345164, 2.0970515136850807, 2.135438978951904, 2.1735035697315945, 2.2109196626227776, 2.247372011312771, 2.2825546870252547, 2.3161701590532235, 2.347928503715281, 2.377546731167741, 2.404748220491236, 2.429262254358821, 2.450823645392045, 2.469172447030505, 2.4840537423865774, 2.495217505137058, 2.502418527023665, 2.5054164070002467, 2.5039755974812308, 2.497865503517941, 2.486860631061015, 2.470740780762138, 2.44929128403000
# ...

# %%
import math
import numpy as np
def func(x):
    return math.sin(x/5.) * math.exp(x/10.) + 5 * math.exp(-x/2.)
x = np.arange(1.,16.,0.2)
type(x)
# Out:
# numpy.ndarray
